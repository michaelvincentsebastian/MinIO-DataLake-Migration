# %%
import duckdb
import pandas as pd

# %%
# filePath1 = 'dataDepok.parquet'
# filePath2 = 'dataBekasi.parquet'
filePathBalikpapan = '../data-lakehouse/managedStoreData/staging/dataBalikpapan/ducklake-019ae9eb-a282-7d56-aa57-f70a8e6741b3.parquet'

# %%
# df1 = pd.read_parquet(filePath1)
# df2 = pd.read_parquet(filePath2)
df3 = pd.read_parquet(filePathBalikpapan)

# %%
df3
# Out:
#                        Nama_Sekolah                Provinsi   Kota_Kabupaten  \
# 0    SD NEGERI 001 BALIKPAPAN UTARA  Prov. Kalimantan Timur  Kota Balikpapan
# 1    SD NEGERI 004 BALIKPAPAN UTARA  Prov. Kalimantan Timur  Kota Balikpapan
# 2    SD NEGERI 009 BALIKPAPAN UTARA  Prov. Kalimantan Timur  Kota Balikpapan
# 3    SD NEGERI 006 BALIKPAPAN UTARA  Prov. Kalimantan Timur  Kota Balikpapan
# 4    SD NEGERI 003 BALIKPAPAN UTARA  Prov. Kalimantan Timur  Kota Balikpapan
# ..                              ...                     ...              ...
# 252         SMP NEGERI 9 BALIKPAPAN  Prov. Kalimantan Timur  Kota Balikpapan
# 253        SMP NEGERI 21 BALIKPAPAN  Prov. Kalimantan Timur  Kota Balikpapan
# 254           SMP PGRI 7 BALIKPAPAN  Prov. Kalimantan Timur  Kota Balikpapan
# 255         SMAN 8 BALIKPAPAN BARAT  Prov. Kalimantan Timur  Kota Balikpapan
# 256    SMKS IBNU KHALDUN BALIKPAPAN  Prov. Kalimantan Timur  Kota Balikpapan
#
# ...
