# %%
import duckdb

# %%
con = duckdb.connect()
con.sql("INSTALL httpfs; LOAD httpfs;")

# %%
parquet = 'staging/parquet/duckdb/jawaBarat/jakarta.parquet'
csv = 'staging/csv/duckdb/jawaBarat/jakarta.csv'

# %%
minioAuth = {
    'accessKey': 'minioadmin',
    'secretKey': 'miniopassword',
    'bucket': 'data-dapodik-kemendikdasmen',
    'endpoint': 'http://localhost:9000'
}

minioEndPoint = minioAuth['endpoint'].replace('http://', '')

# MinIO Setup for DuckDB
con.sql(f"SET s3_endpoint = '{minioEndPoint}';") 
con.sql(f"SET s3_access_key_id = '{minioAuth['accessKey']}';")
con.sql(f"SET s3_secret_access_key = '{minioAuth['secretKey']}';")
con.sql("SET s3_use_ssl = false;")
con.sql("SET s3_url_style = 'path';")

# %%
endpointParquet = f"s3://{minioAuth['bucket']}/{parquet}"
endpointcsv = f"s3://{minioAuth['bucket']}/{csv}"

# %% [markdown]
# DUCKDB

# %%
try:
    parquetDuckDB = con.sql(f"SELECT Operator from read_parquet('{endpointParquet}')")
    print(parquetDuckDB)
except Exception as e:
    print(f"{e}")
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 try:
# ----> 2     parquetDuckDB = con.sql(f"SELECT Operator from read_parquet('{endpointParquet}')")
#       3     print(parquetDuckDB)
#
# IOException: IO Error: Could not establish connection error for HTTP HEAD to 'http://localhost:9000/data-dapodik-kemendikdasmen/staging/parquet/duckdb/jawaBarat/jakarta.parquet'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       3     print(parquetDuckDB)
#       4 except Exception as e:
# ----> 5     print(f"{e}")
#
# KeyboardInterrupt:

# %%
try:
    csvDuckDB = con.sql(f"SELECT Operator FROM read_csv('{endpointcsv}');")
    print(csvDuckDB)
except Exception as e:
    print(f"{e}")
# Out:
# ┌────────────────────────┐
# │        Operator        │
# │        varchar         │
# ├────────────────────────┤
# │ Indrawan Hadi Saputra  │
# │ Hafiz Nurul Ikhsan     │
# │ Didi Nurhadi           │
# │ Chairullah             │
# │ Muhammad Andre Anizar  │
# │ Arie Gunawan           │
# │ Suprayogi              │
# │ Yusup Mulyana          │
# │ Feqo Putra Ajiansya    │
# │ Uki Ismahadi           │
# │      ·                 │
# │      ·                 │
# │      ·                 │
# │ Marantika Kenanga Dewi │
# │ Diana Layla R          │
# │ Dewi Saparyati         │
# │ Novy Reyhana           │
# │ Yusuf Takbirudin       │
# │ Slamet Mulyadi         │
# │ Heribertus Rudiyanto   │
# │ Syaiful Amri           │
# │ Mohammad Firmandaz     │
# │ Boby Dwi Andika S.     │
# ├────────────────────────┤
# │  1753 rows (20 shown)  │
# └────────────────────────┘
